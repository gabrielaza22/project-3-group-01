# %%
# Data science
import pandas as pd

# API
import requests
import json

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func

# %%
# Read the CSV files
df1 = pd.read_csv('Resources/parks.csv')
df = pd.read_csv('Resources/species.csv')

# %%
df1.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65     -80.08

# %%
df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# 0      Approved        Present      Native      Rare    Resident
# 1      Approved        Present      Native  Abundant         NaN
# 2      Approved        Present  Not Native    Common         NaN
# 3      Approved  Not Confirmed      Native       NaN         NaN
# 4      Approved        Present     Unknown    Common     Breeder
#
#   Conservation Status
# 0                 NaN
# 1                 NaN
# 2  Species of Concern
# 3          Endangered
# 4                 NaN

# %%
#drop_list = ["Record Status", "Occurrence", "Nativeness", "Abundance", "Seasonality"]
df.drop(["Record Status", "Occurrence", "Nativeness", "Abundance", "Seasonality"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Conservation Status
# 0                 NaN
# 1                 NaN
# 2  Species of Concern
# 3          Endangered
# 4                 NaN

# %%
# Create engine for conection to the SQLite
engine = create_engine('sqlite:///national_parks.sqlite')

# Save the dataframes to the database
df1.to_sql('parks', engine, index=False, if_exists='replace')
df.to_sql('species', engine, index=False, if_exists='replace')
# Out:
# 119248

# %%
# Read the data from the database
with engine.connect() as connection:
    parks_table = pd.read_sql('SELECT * FROM parks', connection)
    species_table = pd.read_sql('SELECT * FROM species', connection)

species_table.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Conservation Status
# 0                None
# 1                None
# 2  Species of Concern
# 3          Endangered
# 4                None

# %%
parks_table.head(20)
# Out:
#    Park Code                                       Park Name   State    Acres  \
# 0       ACAD                            Acadia National Park      ME    47390
# 1       ARCH                            Arches National Park      UT    76519
# 2       BADL                          Badlands National Park      SD   242756
# 3       BIBE                          Big Bend National Park      TX   801163
# 4       BISC                          Biscayne National Park      FL   172924
# 5       BLCA      Black Canyon of the Gunnison National Park      CO    32950
# 6       BRCA                      Bryce Canyon National Park      UT    35835
# 7       CANY                       Canyonlands National Park      UT   337598
# 8       CARE                      Capitol Reef National Park      UT   241904
# 9       CAVE                  Carlsbad Caverns National Park      NM    46766
# 10      CHIS                   Channel Islands National Park      CA   249561
# 11      CONG                          Congaree National Park      SC    26546
# 12      CRLA                       Crater Lake National Park      OR   183224
# 13      CUVA                   Cuyahoga Valley National Park      OH    32950
# 14      DENA               Denali National Park and Preserve      AK  3372402
# 15      DEVA                      Death Valley National Park  CA, NV  4740912
# 16      DRTO                      Dry Tortugas National Park      FL    64701
# 17      EVER                        Everglades National Park      FL  1508538
# 18      GAAR  Gates Of The Arctic National Park and Preserve      AK  7523898
# 19      GLAC                           Glacier National Park      MT  1013572
#
#     Latitude  Longitude
# 0      44.35     -68.21
# 1      38.68    -109.57
# 2      43.75    -102.50
# 3      29.25    -103.25
# 4      25.65     -80.08
# 5      38.57    -107.72
# 6      37.57    -112.18
# 7      38.20    -109.93
# 8      38.20    -111.17
# 9      32.17    -104.44
# 10     34.01    -119.42
# 11     33.78     -80.78
# 12     42.94    -122.10
# 13     41.24     -81.55
# 14     63.33    -150.50
# 15     36.24    -116.82
# 16     24.63     -82.87
# 17     25.32     -80.93
# 18     67.78    -153.30
# 19     48.80    -114.00

# %%
# Split parks with multiple states into duplicate rows with one for each state

query = """
    WITH split_states AS (
        SELECT
            p."Park Code",
            p."Park Name",
            TRIM(CASE
                WHEN INSTR(p.State, ', ') > 0 THEN SUBSTR(p.State, 1, INSTR(p.State, ', ') - 1)
                ELSE p.State
            END) AS State,
            p.Acres,
            p.Latitude,
            p.Longitude
        FROM
            parks AS p
        UNION
        SELECT
            p."Park Code",
            p."Park Name",
            TRIM(CASE
                WHEN INSTR(p.State, ', ') > 0 THEN SUBSTR(p.State, INSTR(p.State, ', ') + 1)
                ELSE ''
            END) AS State,
            p.Acres,
            p.Latitude,
            p.Longitude
        FROM
            parks AS p
        UNION
        SELECT
            p."Park Code",
            p."Park Name",
            TRIM(CASE
                WHEN INSTR(p.State, ', ') > 0 THEN SUBSTR(p.State, INSTR(p.State, ', ') + 2)
                ELSE ''
            END) AS State,
            p.Acres,
            p.Latitude,
            p.Longitude
        FROM
            parks AS p
    )
    SELECT
        s."Species ID",
        s.Category,
        s."Order",
        s.Family,
        s."Scientific Name",
        s."Common Names",
        s."Conservation Status",
        t."Park Code",
        t."Park Name",
        TRIM(t.State) AS State,
        t.Acres,
        t.Latitude,
        t.Longitude
    FROM
        split_states as t
    JOIN
        species as s ON s."Park Name" = t."Park Name"
    WHERE
        s."Conservation Status" <> 'None'
        AND TRIM(t.State) <> '';
    """


combined_df = pd.read_sql(text(query), con=engine)
combined_df
# Out:
#      Species ID        Category       Order            Family  \
# 0     ACAD-1002          Mammal   Carnivora           Canidae
# 1     ACAD-1003          Mammal   Carnivora           Canidae
# 2     ACAD-1020          Mammal  Chiroptera  Vespertilionidae
# 3     ACAD-1021          Mammal  Chiroptera  Vespertilionidae
# 4     ACAD-1024          Mammal  Chiroptera  Vespertilionidae
# ...         ...             ...         ...               ...
# 5195  ZION-2176  Vascular Plant     Fabales          Fabaceae
# 5196  ZION-2388  Vascular Plant    Myrtales        Onagraceae
# 5197  ZION-2403  Vascular Plant    Myrtales        Onagraceae
# 5198  ZION-2442  Vascular Plant      Poales        Cyperaceae
# 5199  ZION-2540  Vascular Plant      Poales           Poaceae
#
#                 Scientific Name  \
# 0                 Canis latrans
# 1                   Canis lupus
# 2              Eptesicus fuscus
# 3     Lasionycteris noctivagans
# 4                 Myotis keenii
# ...                         ...
# 5195       Pediomelum epipsilum
# 5196         Camissonia bairdii
# 5197        Epilobium nevadense
# 5198               Carex haysii
# 5199      Eragrostis pectinacea
#
#                                            Common Names Conservation Status  \
# 0                                Coyote, Eastern Coyote  Species of Concern
# 1           Eastern Timber Wolf, Gray Wolf, Timber Wolf          Endangered
# 2                       Big Brown Bat, Common Brown Bat  Species of Concern
# 3                                     Silver-Haired Bat  Species of Concern
# 4     Keen's Myotis, Northern Long-Eared Bat, Northe...  Species of Concern
# ...                                                 ...                 ...
# 5195                                     Kane Breadroot  Species of Concern
# 5196                                 Baird's Camissonia  Species of Concern
# 5197                                 Nevada Willow-Herb  Species of Concern
# 5198                                        Hays' Sedge  Species of Concern
# 5199                                   Tufted Lovegrass  Species of Concern
#
#      Park Code             Park Name State   Acres  Latitude  Longitude
# 0         ACAD  Acadia National Park    ME   47390     44.35     -68.21
# 1         ACAD  Acadia National Park    ME   47390     44.35     -68.21
# 2         ACAD  Acadia National Park    ME   47390     44.35     -68.21
# 3         ACAD  Acadia National Park    ME   47390     44.35     -68.21
# 4         ACAD  Acadia National Park    ME   47390     44.35     -68.21
# ...        ...                   ...   ...     ...       ...        ...
# 5195      ZION    Zion National Park    UT  146598     37.30    -113.05
# 5196      ZION    Zion National Park    UT  146598     37.30    -113.05
# 5197      ZION    Zion National Park    UT  146598     37.30    -113.05
# 5198      ZION    Zion National Park    UT  146598     37.30    -113.05
# 5199      ZION    Zion National Park    UT  146598     37.30    -113.05
#
# [5200 rows x 13 columns]

# %%
# Confirm that states are split
combined_df.loc[combined_df["Park Name"] == "Death Valley National Park"].reset_index(drop=True)
# Out:
#     Species ID Category           Order          Family  \
# 0    DEVA-1013   Mammal    Artiodactyla         Bovidae
# 1    DEVA-1013   Mammal    Artiodactyla         Bovidae
# 2    DEVA-1021   Mammal       Carnivora         Canidae
# 3    DEVA-1021   Mammal       Carnivora         Canidae
# 4    DEVA-1037   Mammal       Carnivora      Mustelidae
# ..         ...      ...             ...             ...
# 489  DEVA-5204   Insect         Odonata  Coenagrionidae
# 490  DEVA-5206   Insect         Odonata     Corduliidae
# 491  DEVA-5206   Insect         Odonata     Corduliidae
# 492  DEVA-5365    Fungi  Teloschistales     Caliciaceae
# 493  DEVA-5365    Fungi  Teloschistales     Caliciaceae
#
#                Scientific Name                  Common Names  \
# 0              Ovis canadensis  Bighorn Sheep, Bighorn Sheep
# 1              Ovis canadensis  Bighorn Sheep, Bighorn Sheep
# 2                Canis latrans                        Coyote
# 3                Canis latrans                        Coyote
# 4             Gulo gulo luteus                          None
# ..                         ...                           ...
# 489    Megalagrion xanthomelas                          None
# 490       Somatochlora hineana                Hine's Emerald
# 491       Somatochlora hineana                Hine's Emerald
# 492  Texosporium sancti-jacobi                          None
# 493  Texosporium sancti-jacobi                          None
#
#      Conservation Status Park Code                   Park Name State    Acres  \
# 0     Species of Concern      DEVA  Death Valley National Park    CA  4740912
# 1     Species of Concern      DEVA  Death Valley National Park    NV  4740912
# 2     Species of Concern      DEVA  Death Valley National Park    CA  4740912
# 3     Species of Concern      DEVA  Death Valley National Park    NV  4740912
# 4     Species of Concern      DEVA  Death Valley National Park    CA  4740912
# ..                   ...       ...                         ...   ...      ...
# 489  Proposed Endangered      DEVA  Death Valley National Park    NV  4740912
# 490           Endangered      DEVA  Death Valley National Park    CA  4740912
# 491           Endangered      DEVA  Death Valley National Park    NV  4740912
# 492   Species of Concern      DEVA  Death Valley National Park    CA  4740912
# 493   Species of Concern      DEVA  Death Valley National Park    NV  4740912
#
#      Latitude  Longitude
# 0       36.24    -116.82
# 1       36.24    -116.82
# 2       36.24    -116.82
# 3       36.24    -116.82
# 4       36.24    -116.82
# ..        ...        ...
# 489     36.24    -116.82
# 490     36.24    -116.82
# 491     36.24    -116.82
# 492     36.24    -116.82
# 493     36.24    -116.82
#
# [494 rows x 13 columns]

# %%
# Save the dataframe to the database
combined_df.to_sql('combined', engine, index=False, if_exists='replace')
# Out:
# 5200

# %%
# INSPECT to confirm existence

# Create the inspector and connect it to the engine
inspector_gadget = inspect(engine)

# Collect the names of tables within the database
tables = inspector_gadget.get_table_names()

# print metadata for each table
for table in tables:
    print(table)
    print("-----------")
    
    # get columns
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column["name"], column["type"])

    print()
# Out:
# combined
# -----------
# Species ID TEXT
# Category TEXT
# Order TEXT
# Family TEXT
# Scientific Name TEXT
# Common Names TEXT
# Conservation Status TEXT
# Park Code TEXT
# Park Name TEXT
# State TEXT
# Acres BIGINT
# Latitude FLOAT
# Longitude FLOAT
#
# conservation
# -----------
# Park Name TEXT
# Latitude FLOAT
# Longitude FLOAT
# Conservation Status TEXT
# Species Count BIGINT
# State TEXT
# Acres BIGINT
#
# parks
# -----------
# Park Code TEXT
# Park Name TEXT
# State TEXT
# Acres BIGINT
# Latitude FLOAT
# Longitude FLOAT
#
# species
# -----------
# Species ID TEXT
# Park Name TEXT
# Category TEXT
# Order TEXT
# Family TEXT
# Scientific Name TEXT
# Common Names TEXT
# Conservation Status TEXT

# %%
print(combined_df["State"].nunique())
combined_df.State.sort_values().unique()
# Out:
# 27
# array(['AK', 'AR', 'AZ', 'CA', 'CO', 'FL', 'HI', 'KY', 'ME', 'MI', 'MN',
#        'MT', 'MT, ID', 'NC', 'ND', 'NM', 'NV', 'OH', 'OR', 'SC', 'SD',
#        'TN', 'TX', 'UT', 'VA', 'WA', 'WY'], dtype=object)

# %%
print(combined_df["Conservation Status"].nunique())
combined_df["Conservation Status"].unique()
# Out:
# 11
# array(['Species of Concern', 'Endangered', 'In Recovery', 'Threatened',
#        'Under Review', 'Proposed Threatened', 'Extinct',
#        'Proposed Endangered', 'Resident', 'Breeder', 'Migratory'],
#       dtype=object)

# %%
# Q3: How does the size of different parks compare with the conservation status of the animals in each park across the country?

# %%
query = """
    SELECT
        "Park Name",
        Latitude,
        Longitude,
        "Conservation Status",
        COUNT ("Conservation Status") AS "Species Count",
        State,
        Acres
    FROM
        combined
    WHERE
        "Conservation Status" IN ('Endangered', 'Threatened', 'Species of Concern', 'Under Review')
    GROUP BY 
        "Park Name", "State", "Conservation Status"
    ORDER BY
        Acres DESC
    """

q3_df = pd.read_sql(text(query), con=engine)
q3_df.head(15)
# Out:
#                                          Park Name  Latitude  Longitude  \
# 0   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 1   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 2   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 3   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 4   Gates Of The Arctic National Park and Preserve     67.78    -153.30
# 5                       Death Valley National Park     36.24    -116.82
# 6                       Death Valley National Park     36.24    -116.82
# 7                       Death Valley National Park     36.24    -116.82
# 8                       Death Valley National Park     36.24    -116.82
# 9                       Death Valley National Park     36.24    -116.82
# 10                      Death Valley National Park     36.24    -116.82
# 11                      Death Valley National Park     36.24    -116.82
# 12                      Death Valley National Park     36.24    -116.82
# 13               Katmai National Park and Preserve     58.50    -155.00
# 14               Katmai National Park and Preserve     58.50    -155.00
#
#    Conservation Status  Species Count State    Acres
# 0           Endangered              5    AK  8323148
# 1   Species of Concern             40    AK  8323148
# 2           Threatened              3    AK  8323148
# 3         Under Review              2    AK  8323148
# 4   Species of Concern             21    AK  7523898
# 5           Endangered             24    CA  4740912
# 6   Species of Concern            177    CA  4740912
# 7           Threatened             16    CA  4740912
# 8         Under Review             27    CA  4740912
# 9           Endangered             24    NV  4740912
# 10  Species of Concern            177    NV  4740912
# 11          Threatened             16    NV  4740912
# 12        Under Review             27    NV  4740912
# 13          Endangered              6    AK  3674530
# 14  Species of Concern             31    AK  3674530

# %%
q3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Park Name            220 non-null    object
#  1   Latitude             220 non-null    float64
#  2   Longitude            220 non-null    float64
#  3   Conservation Status  220 non-null    object
#  4   Species Count        220 non-null    int64
#  5   State                220 non-null    object
#  6   Acres                220 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 12.2+ KB

# %%
q3_df.value_counts("Conservation Status")
# Out:
# Conservation Status
# Species of Concern    59
# Threatened            56
# Endangered            54
# Under Review          51
# Name: count, dtype: int64

# %%
# Total Species count per park
df3 = q3_df.groupby("Park Name")["Species Count"].sum()
df3 = df3.sort_values(ascending=False)
df3
# Out:
# Park Name
# Death Valley National Park                        488
# Great Smoky Mountains National Park               280
# Yellowstone National Park                         182
# Redwood National Park                             162
# Channel Islands National Park                     139
# Big Bend National Park                            136
# Grand Canyon National Park                        132
# Hawaii Volcanoes National Park                    115
# Joshua Tree National Park                         107
# Everglades National Park                          105
# Carlsbad Caverns National Park                    102
# Great Basin National Park                          99
# Zion National Park                                 98
# Saguaro National Park                              95
# Yosemite National Park                             94
# Shenandoah National Park                           91
# Capitol Reef National Park                         91
# Mesa Verde National Park                           89
# Guadalupe Mountains National Park                  89
# Sequoia and Kings Canyon National Parks            87
# Lassen Volcanic National Park                      87
# Olympic National Park                              85
# Grand Teton National Park                          84
# Haleakala National Park                            81
# Glacier National Park                              81
# Canyonlands National Park                          79
# Crater Lake National Park                          79
# Petrified Forest National Park                     79
# North Cascades National Park                       79
# Mammoth Cave National Park                         79
# Pinnacles National Park                            76
# Arches National Park                               74
# Acadia National Park                               73
# Bryce Canyon National Park                         72
# Hot Springs National Park                          72
# Rocky Mountain National Park                       72
# Wind Cave National Park                            69
# Badlands National Park                             68
# Black Canyon of the Gunnison National Park         65
# Isle Royale National Park                          64
# Biscayne National Park                             61
# Glacier Bay National Park and Preserve             60
# Cuyahoga Valley National Park                      59
# Mount Rainier National Park                        59
# Dry Tortugas National Park                         59
# Great Sand Dunes National Park and Preserve        57
# Voyageurs National Park                            57
# Theodore Roosevelt National Park                   54
# Wrangell - St Elias National Park and Preserve     50
# Kenai Fjords National Park                         48
# Congaree National Park                             48
# Lake Clark National Park and Preserve              42
# Katmai National Park and Preserve                  41
# Denali National Park and Preserve                  32
# Kobuk Valley National Park                         23
# Gates Of The Arctic National Park and Preserve     21
# Name: Species Count, dtype: int64

# %%
# df_split = q3_df.assign(State=q3_df["State"].str.split(", ")).explode("State")

# df_split = df_split.reset_index(drop=True)

# df_split.head(20)
# Out:
#                                          Park Name  Latitude  Longitude  \
# 0   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 1   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 2   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 3   Wrangell - St Elias National Park and Preserve     61.00    -142.00
# 4   Gates Of The Arctic National Park and Preserve     67.78    -153.30
# 5                       Death Valley National Park     36.24    -116.82
# 6                       Death Valley National Park     36.24    -116.82
# 7                       Death Valley National Park     36.24    -116.82
# 8                       Death Valley National Park     36.24    -116.82
# 9                Katmai National Park and Preserve     58.50    -155.00
# 10               Katmai National Park and Preserve     58.50    -155.00
# 11               Katmai National Park and Preserve     58.50    -155.00
# 12               Katmai National Park and Preserve     58.50    -155.00
# 13               Denali National Park and Preserve     63.33    -150.50
# 14               Denali National Park and Preserve     63.33    -150.50
# 15               Denali National Park and Preserve     63.33    -150.50
# 16          Glacier Bay National Park and Preserve     58.50    -137.00
# 17          Glacier Bay National Park and Preserve     58.50    -137.00
# 18          Glacier Bay National Park and Preserve     58.50    -137.00
# 19          Glacier Bay National Park and Preserve     58.50    -137.00
#
#    Conservation Status  Species Count State    Acres
# 0           Endangered              5    AK  8323148
# 1   Species of Concern             40    AK  8323148
# 2           Threatened              3    AK  8323148
# 3         Under Review              2    AK  8323148
# 4   Species of Concern             21    AK  7523898
# 5           Endangered             48    CA  4740912
# 6   Species of Concern            354    CA  4740912
# 7           Threatened             32    CA  4740912
# 8         Under Review             54    CA  4740912
# 9           Endangered              6    AK  3674530
# 10  Species of Concern             31    AK  3674530
# 11          Threatened              2    AK  3674530
# 12        Under Review              2    AK  3674530
# 13  Species of Concern             30    AK  3372402
# 14          Threatened              1    AK  3372402
# 15        Under Review              1    AK  3372402
# 16          Endangered              9    AK  3224840
# 17  Species of Concern             47    AK  3224840
# 18          Threatened              3    AK  3224840
# 19        Under Review              1    AK  3224840

# %%
# Save the dataframes to the database
q3_df.to_sql('conservation', engine, index=False, if_exists='replace')
# Out:
# 220
